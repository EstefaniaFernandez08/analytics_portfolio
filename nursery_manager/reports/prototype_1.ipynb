# %% [markdown]
# <div style="max-width: 850px; margin: 0 auto;">
#     <!-- Sección 1: Presentación y Enfoque -->
#     <div style="padding: 25px; background-color: rgba(255, 255, 255, 0.95);
#             border-radius: 12px; box-shadow: 0 4px 15px rgba(0,0,0,0.08);
#             border: 2px solid #e3d0b3; margin-bottom: 25px;">
#         <!-- Título Principal -->
#         <h1 style="color: #4a6b3d; margin-bottom: 10px; font-size: 38px;
#                 text-align: center; letter-spacing: 0.5px;">
#             🌿 VIVERO RAÍCES DORADAS
#         </h1>
#         <!-- Subtítulo -->
#         <h2 style="color: #926e41; font-size: 22px; margin-bottom: 25px;
#                 text-align: center; font-style: italic; border-bottom: 2px solid #f0f0f0;
#                 padding-bottom: 15px;">
#             Especialistas en plantas adaptadas a Alameda del Río
#         </h2>
#         <!-- Introducción -->
#         <div style="margin-bottom: 25px;">
#             <p style="font-size: 18px; color: #555; line-height: 1.6; margin-bottom: 15px;">
#                 <strong style="color: #4a6b3d;">Desde Mayo 2025</strong>, cultivamos con dedicación
#                 plantas y árboles específicamente aclimatados para prosperar en el espacio público
#                 de nuestra comunidad.
#             </p>
#             <p style="font-size: 18px; color: #555; line-height: 1.6; margin-bottom: 15px;">
#                 Nuestra <strong style="color: #926e41;">pericia basada en datos</strong> nos permite
#                 ofrecerte especies que llegan saludables y listas para crecer, gracias a un
#                 <strong>riguroso control de calidad y salubridad</strong> adaptado a cada variedad.
#             </p>
#             <p style="font-size: 18px; color: #555; line-height: 1.6;">
#                 Trabajamos exclusivamente con <strong style="color: #4a6b3d;">organizaciones</strong>
#                 que comparten nuestra visión de crear espacios verdes sostenibles.
#             </p>
#         </div>
#         <!-- Datos de Confianza -->
#         <div style="background: linear-gradient(to right, #f9f5f0, #f0f7e9);
#                 padding: 20px; border-radius: 8px; margin: 20px 0;
#                 border: 1px solid #e3d0b3; text-align: center;">
#             <div style="display: flex; justify-content: center; flex-wrap: wrap;
#                     gap: 15px; margin: 15px 0;">
#                 <div style="flex: 1; min-width: 150px; padding: 15px;
#                         background-color: white; border-radius: 8px;
#                         border: 2px solid #4a6b3d;">
#                     <div style="font-size: 24px; font-weight: bold; color: #4a6b3d;">35+</div>
#                     <div style="font-size: 14px; color: #777;">Especies disponibles</div>
#                 </div>
#                 <div style="flex: 1; min-width: 150px; padding: 15px;
#                         background-color: white; border-radius: 8px;
#                         border: 2px solid #926e41;">
#                     <div style="font-size: 24px; font-weight: bold; color: #926e41;">900+</div>
#                     <div style="font-size: 14px; color: #777;">Plantas en inventario</div>
#                 </div>
#             </div>
#             <p style="font-size: 16px; color: #666; font-style: italic; margin-top: 10px;">
#                 Cultivadas localmente para garantizar adaptación y vitalidad
#             </p>
#         </div>
#     </div>
#     <!-- Sección 2: Oferta y Disponibilidad -->
#     <div style="padding: 25px; background-color: rgba(255, 255, 255, 0.95);
#             border-radius: 12px; box-shadow: 0 4px 15px rgba(0,0,0,0.08);
#             border: 2px solid #e3d0b3;">
#         <h2 style="color: #4a6b3d; margin-bottom: 20px; font-size: 28px;
#                 text-align: center;">
#             🌱 Nuestro Catálogo Disponible
#         </h2>
#         <p style="font-size: 18px; color: #555; line-height: 1.6; margin-bottom: 25px;
#                 text-align: center;">
#             Selecciona entre nuestras tres categorías principales,
#             cada una con plantas que han demostrado excelente adaptación
#             a las condiciones locales de Alameda del Río.
#         </p>
#         <!-- Categorías -->
#         <div style="display: flex; justify-content: space-around; flex-wrap: wrap;
#                 gap: 20px; margin: 30px 0;">
#             <!-- Plantas Ornamentales -->
#             <div style="flex: 1; min-width: 220px; padding: 20px;
#                     background-color: white; border-radius: 8px;
#                     border: 2px solid #4a6b3d; text-align: center;
#                     box-shadow: 0 3px 10px rgba(0,0,0,0.05);">
#                 <div style="font-size: 32px; color: #4a6b3d; margin-bottom: 15px;">🌺</div>
#                 <h3 style="font-size: 20px; font-weight: bold; color: #4a6b3d;
#                         margin-bottom: 10px;">
#                     Plantas Ornamentales
#                 </h3>
#                 <div style="font-size: 28px; font-weight: bold; color: #4a6b3d;
#                         margin: 15px 0;">
#                     [X] unidades
#                 </div>
#                 <div style="font-size: 15px; color: #777;">
#                     Ideales para jardinería y embellecimiento de espacios
#                 </div>
#             </div>
#             <!-- Árboles Ornamentales -->
#             <div style="flex: 1; min-width: 220px; padding: 20px;
#                     background-color: white; border-radius: 8px;
#                     border: 2px solid #926e41; text-align: center;
#                     box-shadow: 0 3px 10px rgba(0,0,0,0.05);">
#                 <div style="font-size: 32px; color: #926e41; margin-bottom: 15px;">🌳</div>
#                 <h3 style="font-size: 20px; font-weight: bold; color: #926e41;
#                         margin-bottom: 10px;">
#                     Árboles Ornamentales
#                 </h3>
#                 <div style="font-size: 28px; font-weight: bold; color: #926e41;
#                         margin: 15px 0;">
#                     [Y] unidades
#                 </div>
#                 <div style="font-size: 15px; color: #777;">
#                     Para sombra, estructura y valor paisajístico
#                 </div>
#             </div>
#             <!-- Árboles Frutales -->
#             <div style="flex: 1; min-width: 220px; padding: 20px;
#                     background-color: white; border-radius: 8px;
#                     border: 2px solid #e7a13c; text-align: center;
#                     box-shadow: 0 3px 10px rgba(0,0,0,0.05);">
#                 <div style="font-size: 32px; color: #e7a13c; margin-bottom: 15px;">🍊</div>
#                 <h3 style="font-size: 20px; font-weight: bold; color: #e7a13c;
#                         margin-bottom: 10px;">
#                     Árboles Frutales
#                 </h3>
#                 <div style="font-size: 28px; font-weight: bold; color: #e7a13c;
#                         margin: 15px 0;">
#                     [Z] unidades
#                 </div>
#                 <div style="font-size: 15px; color: #777;">
#                     Producción local y valor comunitario
#                 </div>
#             </div>
#         </div>
#         <!-- Tabla de Especies -->
#         <div style="margin-top: 40px;">
#             <h3 style="color: #4a6b3d; margin-bottom: 20px; font-size: 22px;
#                     border-bottom: 2px solid #f0f0f0; padding-bottom: 10px;">
#                 📋 Disponibilidad por Especie
#             </h3>
#             <div style="overflow-x: auto; margin-top: 15px;">
#                 <table style="width: 100%; border-collapse: collapse;
#                         border: 1px solid #e3d0b3; background-color: white;">
#                     <thead>
#                         <tr style="background-color: #4a6b3d; color: white;">
#                             <th style="padding: 14px 16px; text-align: left;
#                                     border: 1px solid #e3d0b3; font-size: 16px;">
#                                 Especie
#                             </th>
#                             <th style="padding: 14px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; font-size: 16px;">
#                                 Disponible
#                             </th>
#                             <th style="padding: 14px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; font-size: 16px;">
#                                 Altura (cm)
#                             </th>
#                             <th style="padding: 14px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; font-size: 16px;">
#                                 Categoría
#                             </th>
#                         </tr>
#                     </thead>
#                     <tbody>
#                         <!-- Fila de ejemplo 1 -->
#                         <tr style="border-bottom: 1px solid #f0f0f0;">
#                             <td style="padding: 12px 16px; border: 1px solid #e3d0b3;
#                                     font-weight: bold; color: #555;">
#                                 [Nombre Común 1]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; color: #4a6b3d;
#                                     font-weight: bold;">
#                                 [Cantidad]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; color: #555;">
#                                 [Altura promedio]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3;">
#                                 <span style="background-color: #f0f7e9; color: #4a6b3d;
#                                         padding: 4px 10px; border-radius: 4px;
#                                         font-size: 14px;">
#                                     [Categoría]
#                                 </span>
#                             </td>
#                         </tr>
#                         <!-- Fila de ejemplo 2 -->
#                         <tr style="border-bottom: 1px solid #f0f0f0;
#                                 background-color: #f9f9f9;">
#                             <td style="padding: 12px 16px; border: 1px solid #e3d0b3;
#                                     font-weight: bold; color: #555;">
#                                 [Nombre Común 2]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; color: #4a6b3d;
#                                     font-weight: bold;">
#                                 [Cantidad]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3; color: #555;">
#                                 [Altura promedio]
#                             </td>
#                             <td style="padding: 12px 16px; text-align: center;
#                                     border: 1px solid #e3d0b3;">
#                                 <span style="background-color: #f9f5f0; color: #926e41;
#                                         padding: 4px 10px; border-radius: 4px;
#                                         font-size: 14px;">
#                                     [Categoría]
#                                 </span>
#                             </td>
#                         </tr>
#                         <!-- Más filas aquí -->
#                         <tr>
#                             <td colspan="4" style="padding: 15px; text-align: center;
#                                     font-style: italic; color: #777; background-color: #f9f9f9;">
#                                 * Información actualizada al [fecha]. Contáctanos para consultar disponibilidad específica.
#                             </td>
#                         </tr>
#                     </tbody>
#                 </table>
#             </div>
#             <!-- Nota de Calidad -->
#             <div style="margin-top: 20px; padding: 15px; background-color: #f0f7e9;
#                     border-radius: 6px; border-left: 4px solid #4a6b3d;">
#                 <p style="font-size: 16px; color: #4a6b3d; margin: 0;">
#                     <strong>✅ Garantía de Calidad:</strong> Todas nuestras plantas pasan por
#                     controles de salubridad y están listas para trasplante inmediato.
#                 </p>
#             </div>
#         </div>
#         <!-- Llamada a la acción -->
#         <div style="text-align: center; margin-top: 30px; padding-top: 25px;
#                 border-top: 2px solid #f0f0f0;">
#             <p style="font-size: 18px; color: #4a6b3d; font-weight: bold;
#                     margin-bottom: 15px;">
#                 ¿Interesado en alguna especie o necesitas asesoría para tu proyecto?
#             </p>
#             <p style="font-size: 16px; color: #666; margin-bottom: 20px;">
#                 Estamos listos para ayudarte a seleccionar las mejores opciones
#                 para tu organización.
#             </p>
#         </div>
#     </div>
# </div>
